# %% [markdown]
# # Module 2 — Spatial Transformations and SE(3)
# ## Unit 4 — SE(3) Transformations
# ### Lesson 4.3 — The SE(3) Transformation
#
# *Physical AI Curriculum · hands-on notebook. Run **Kernel → Restart & Run All**.*

# %%
import numpy as np
def se3(R,t):
    T=np.eye(4); T[:3,:3]=R; T[:3,3]=t; return T
def Rz(d):
    a=np.radians(d); c,s=np.cos(a),np.sin(a); return np.array([[c,-s,0],[s,c,0],[0,0,1.0]])
T=se3(Rz(90),[0.4,0.3,0.9])
print('SE(3) pose =\n', np.round(T,3))
print('bottom row:', T[3])

# %% [markdown]
# ## Coding Exercise (§8)
# Build an SE(3), read back R and t, confirm the bottom row is [0 0 0 1].

# %%
# YOUR CODE HERE
import numpy as np
R_back=T[:3,:3]; t_back=T[:3,3]
print('t read back:', np.round(t_back,3))
print('bottom row ok:', np.allclose(T[3],[0,0,0,1]))

# %% [markdown]
# ## Check your work

# %%
import numpy as np
assert T.shape==(4,4)
assert np.allclose(T[3],[0,0,0,1])
assert np.allclose(T[:3,3],[0.4,0.3,0.9])
print('All checks passed.')
