# %% [markdown]
# # Lesson 1.4 Notebook — Why Transformations Matter (Unit 1 Recap)
# Consolidation: pose between frames; 2x2 can't translate. Run **Kernel → Restart & Run All**.

# %%
import numpy as np
# rotation works as a 2x2; translation does not
R=np.array([[0,-1],[1,0]])
print('rotate (1,0):', R@np.array([1,0]), ' (2x2 handles rotation)')
print('translate origin? 2x2 @ (0,0) =', R@np.array([0,0]), ' -> stuck at origin')
print('Unit 2 fixes this with homogeneous coordinates.')

# %% [markdown]
# ## Check your work

# %%
import numpy as np
assert np.allclose(R@np.array([1,0]),[0,1])
assert np.allclose(R@np.array([0,0]),[0,0])
print('All checks passed.')
