# %% [markdown]
# # Module 2 — Spatial Transformations and SE(3)
# ## Unit 2 — Homogeneous Coordinates
# ### Lesson 2.2 — Points vs Directions
#
# *Physical AI Curriculum · hands-on notebook. Run **Kernel → Restart & Run All**.*

# %%
import numpy as np
def T(tx,ty): return np.array([[1,0,tx],[0,1,ty],[0,0,1.0]])
point     = np.array([2.0,3.0,1.0])   # w=1
direction = np.array([2.0,3.0,0.0])   # w=0
M=T(5,0)
print('point     after T(5,0):', M@point,     '(moved)')
print('direction after T(5,0):', M@direction, '(unchanged)')

# %% [markdown]
# ## Coding Exercise (§8)
# A displacement is the difference of two points -> w=0. Verify.

# %%
# YOUR CODE HERE
import numpy as np
a=np.array([4.,5.,1.]); b=np.array([1.,2.,1.])
disp=a-b
print('a - b =', disp, ' -> w =', disp[2], '(a direction)')

# %% [markdown]
# ## Check your work

# %%
import numpy as np
assert np.allclose(T(5,0)@np.array([2,3,1.]), [7,3,1])
assert np.allclose(T(5,0)@np.array([2,3,0.]), [2,3,0])
assert (np.array([4.,5.,1.])-np.array([1.,2.,1.]))[2]==0
print('All checks passed.')
