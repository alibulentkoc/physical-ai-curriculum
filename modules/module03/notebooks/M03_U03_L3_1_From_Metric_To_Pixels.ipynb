# %% [markdown]
# # Module 3 — Camera Geometry and Robotic Perception
# ## Unit 3 — Camera Intrinsics
# ### Lesson 3.1 — From Metric to Pixels
#
# *Physical AI Curriculum · hands-on notebook. Run **Kernel → Restart & Run All**.*

# %%
import numpy as np
def focal_pixels(f_m, pixel_size): return f_m/pixel_size
f_m=4.0      # mm
for s in [0.005, 0.0025]:
    print('pixel size %.4f mm -> f_x = %.0f px'%(s, focal_pixels(f_m,s)))

# %% [markdown]
# ## Coding Exercise (§8)
# Convert metric projection to pixel offsets; verify halving pixel size doubles the offset.

# %%
# YOUR CODE HERE
import numpy as np
def u_offset(f_m, s, X, Z): return (f_m/s)*(X/Z)
o1=u_offset(4.0,0.005,0.06,0.3)
o2=u_offset(4.0,0.0025,0.06,0.3)
print('offset @0.005mm: %.0f px ; @0.0025mm: %.0f px ; doubled: %s'%(o1,o2,np.isclose(o2,2*o1)))

# %% [markdown]
# ## Check your work

# %%
import numpy as np
assert np.isclose(focal_pixels(4.0,0.005), 800)
assert np.isclose(u_offset(4.0,0.005,0.06,0.3), 160)
print('All checks passed.')
