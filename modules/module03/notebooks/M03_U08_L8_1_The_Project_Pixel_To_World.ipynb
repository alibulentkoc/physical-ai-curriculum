# %% [markdown]
# # Module 3 — Camera Geometry and Robotic Perception
# ## Unit 8 — Mini Project: See the Fruit, Place It in the World
# ### Lesson 8.1 — The Project: Pixel to World
#
# *Physical AI Curriculum · hands-on notebook. Run **Kernel → Restart & Run All**.*

# %%
import numpy as np
# Project contract: given pixel, K, distortion, depth, extrinsics -> P_w + checks
K=np.array([[800,0,320],[0,800,240],[0,0,1.0]])
pixel=(480,160); Z=0.3; distCoeffs=np.zeros(5)
T_ac=np.eye(4); T_ac[:3,3]=[0,0,0.1]
T_wa=np.eye(4); T_wa[:3,3]=[1.0,0.5,0.0]
print('inputs ready; reference output P_w = (1.06, 0.47, 0.4)')

# %% [markdown]
# ## Coding Exercise (§8)
# Stub the signature and state the three acceptance checks (implemented in 8.2/8.3).

# %%
# YOUR CODE HERE
checks=['re-projection <=1px','distance preserved','in workspace']
print('acceptance checks:',checks)
assert len(checks)==3

# %% [markdown]
# ## Check your work

# %%
import numpy as np
assert K.shape==(3,3) and T_ac.shape==(4,4) and T_wa.shape==(4,4)
print('All checks passed.')
