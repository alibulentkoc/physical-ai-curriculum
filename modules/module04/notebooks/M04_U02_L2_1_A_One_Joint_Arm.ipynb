# %% [markdown]
# # Module 4 — Forward Kinematics using Denavit–Hartenberg Parameters
# ## Unit 2 — One Joint at a Time
# ### Lesson 2.1 — A One-Joint Arm
#
# *Physical AI Curriculum · hands-on notebook. Run **Kernel → Restart & Run All**.*

# %%
import numpy as np
import matplotlib; matplotlib.use('Agg'); import matplotlib.pyplot as plt
def pose_one_joint(theta, L):
    c,s=np.cos(theta),np.sin(theta)
    return np.array([[c,-s,L*c],[s,c,L*s],[0,0,1.0]])
L=0.5
for deg in [0,45,90]:
    T=pose_one_joint(np.radians(deg),L)
    print(f'theta={deg:>3} pos',np.round(T[:2,2],3),'orient(deg)',round(np.degrees(np.arctan2(T[1,0],T[0,0]))))

# %% [markdown]
# ## Coding Exercise (§8)
# Build the SE(2) pose; verify worked example; plot the swept circle.

# %%
# YOUR CODE HERE
import numpy as np
T=pose_one_joint(np.radians(90),L)
assert np.allclose(T[:2,2],[0,0.5])
ths=np.linspace(0,2*np.pi,100); pts=np.array([pose_one_joint(t,L)[:2,2] for t in ths])
fig,ax=plt.subplots(); ax.plot(pts[:,0],pts[:,1]); ax.set_aspect('equal'); fig.savefig('/tmp/circle.png')
print('circle radius ~', round(float(np.linalg.norm(pts[0])),3))

# %% [markdown]
# ## Check your work

# %%
import numpy as np
assert np.allclose(pose_one_joint(0,L)[:2,2],[0.5,0])
assert np.allclose(pose_one_joint(np.radians(45),L)[:2,2],[0.5*np.cos(np.radians(45))]*2)
print('All checks passed.')
